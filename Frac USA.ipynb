# %% [markdown]
# I used this notebook to clean the US data a little more to make visualizing easier.

# %%
#bring in packages necessary to run this notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read in data
frac_usa = pd.read_csv('data/Master/frac_usa.csv', index_col = 0)
frac_usa
# Out:
# /Users/brookenichols/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                  JobStartDate             JobEndDate       APINumber  \
# 0       4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# 1       4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# 2       4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# 3       4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# 4       4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# ...                       ...                    ...             ...
# 234051  5/23/2021 12:00:00 AM  5/23/2021 12:00:00 AM  42173346750000
# 234052   6/8/2021 12:00:00 AM   6/8/2021 12:00:00 AM  42115334560000
# 234053   6/8/2021 12:00:00 AM   6/8/2021 12:00:00 AM  42115334560000
# ...

# %%
#check size
frac_usa.shape
# Out:
# (4734056, 17)

# %%
#check info
frac_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4734056 entries, 0 to 234055
# Data columns (total 17 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   JobStartDate             object
#  1   JobEndDate               object
#  2   APINumber                int64
#  3   OperatorName             object
#  4   WellName                 object
#  5   Latitude                 float64
#  6   Longitude                float64
#  7   TVD                      float64
#  8   TotalBaseWaterVolume     float64
#  9   TotalBaseNonWaterVolume  float64
#  10  StateName                object
#  11  CountyName               object
#  12  FederalWell              bool
#  13  IndianWell               bool
#  14  IngredientName           object
#  15  PercentHFJob             float64
#  16  MassIngredient           float64
# dtypes: bool(2), float64(7), int64(1), object(7)
# memory usage: 586.9+ MB

# %%
#check for null values
frac_usa.isna().sum()
# Out:
# JobStartDate                  673
# JobEndDate                      0
# APINumber                       0
# OperatorName                    0
# WellName                        0
# Latitude                        0
# Longitude                       0
# TVD                             8
# TotalBaseWaterVolume           48
# TotalBaseNonWaterVolume    130451
# StateName                       0
# CountyName                    134
# FederalWell                     0
# IndianWell                      0
# IngredientName              11239
# PercentHFJob                60176
# MassIngredient              80976
# dtype: int64

# %%
#remove the remaining null values
frac_usa.dropna(inplace = True)

# %%
#drop duplicates
frac_usa.drop_duplicates(inplace = True)

# %%
#reset the frac_usa index after dropping the null values and duplicates
frac_usa.reset_index(drop = True)
# Out:
#                   JobStartDate             JobEndDate       APINumber  \
# 0        4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# 1        4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# 2        4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# 3        4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# 4        4/16/2013 12:00:00 AM  4/23/2013 12:00:00 AM  42311351300000
# ...                        ...                    ...             ...
# 4096859   8/27/2020 5:00:00 AM   9/14/2020 5:00:00 AM  33061046850000
# 4096860   8/27/2020 5:00:00 AM   9/14/2020 5:00:00 AM  33061046850000
# 4096861   8/27/2020 5:00:00 AM   9/14/2020 5:00:00 AM  33061046850000
# 4096862   8/27/2020 5:00:00 AM   9/14/2020 5:00:00 AM  33061046850000
# 4096863   8/27/2020 5:00:00 AM   9/14/2020 5:00:00 AM  33061046850000
#
#                        OperatorName             WellName   Latitude  \
# ...

# %%
#check the data type of each column and confirm there are no null values left
frac_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4096864 entries, 0 to 234020
# Data columns (total 17 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   JobStartDate             object
#  1   JobEndDate               object
#  2   APINumber                int64
#  3   OperatorName             object
#  4   WellName                 object
#  5   Latitude                 float64
#  6   Longitude                float64
#  7   TVD                      float64
#  8   TotalBaseWaterVolume     float64
#  9   TotalBaseNonWaterVolume  float64
#  10  StateName                object
#  11  CountyName               object
#  12  FederalWell              bool
#  13  IndianWell               bool
#  14  IngredientName           object
#  15  PercentHFJob             float64
#  16  MassIngredient           float64
# dtypes: bool(2), float64(7), int64(1), object(7)
# memory usage: 507.9+ MB

# %%
#send frac_master file to folder
#frac_usa.to_csv('data/Master/frac_usa_clean.csv')
